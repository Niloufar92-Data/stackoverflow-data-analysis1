# %% [markdown]
# # Stack Overflow 2017 Developer Survey Analysis
#
# ## Business Understanding
#
# The objective of this project is to analyze the Stack Overflow 2017 Developer Survey to answer the following questions:
#
# 1. What are the most popular programming languages among developers?
#
#
# ## Data Understanding
#
# The dataset used for this analysis is the Stack Overflow 2017 Developer Survey. It contains information about developers' demographics, preferences, and opinions.
#
# The key columns in this dataset that will be used for analysis are:
#
# - `HaveWorkedLanguage`: Programming languages used by developers.

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Question 1: What are the Most Popular Programming Languages Among Developers?

# %%
#Import necessary libraries

import pandas as pd
import numpy as np

#Load the Dataset
df = pd.read_csv(r'C:\Users\nilou\OneDrive\Desktop\Data Science learning\Projects\stackoverflow-data-analysis1\survey_results_public.csv')

# %%
# Show the first few rows to understand the structure

df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51392 entries, 0 to 51391
# Columns: 154 entries, Respondent to ExpectedSalary
# dtypes: float64(6), int64(1), object(147)
# memory usage: 60.4+ MB

# %%
# check all column names
df.columns.tolist()
# Out:
# ['Respondent',
#  'Professional',
#  'ProgramHobby',
#  'Country',
#  'University',
#  'EmploymentStatus',
#  'FormalEducation',
#  'MajorUndergrad',
#  'HomeRemote',
#  'CompanySize',
#  'CompanyType',
#  'YearsProgram',
#  'YearsCodedJob',
#  'YearsCodedJobPast',
#  'DeveloperType',
#  'WebDeveloperType',
#  'MobileDeveloperType',
#  'NonDeveloperType',
#  'CareerSatisfaction',
#  'JobSatisfaction',
#  'ExCoderReturn',
#  'ExCoderNotForMe',
#  'ExCoderBalance',
#  'ExCoder10Years',
#  'ExCoderBelonged',
#  'ExCoderSkills',
#  'ExCoderWillNotCode',
#  'ExCoderActive',
#  'PronounceGIF',
#  'ProblemSolving',
#  'BuildingThings',
#  'LearningNewTech',
#  'BoringDetails',
#  'JobSecurity',
#  'DiversityImportant',
#  'AnnoyingUI',
#  'FriendsDevelopers',
#  'RightWrongWay',
#  'UnderstandComputers',
#  'SeriousWork',
#  'InvestTimeTools',
#  'WorkPayCare',
#  'KinshipDevelopers',
#  'ChallengeMyself',
#  'CompetePeers',
#  'ChangeWorld',
#  'JobSeekingStatus',
#  'HoursPerWeek',
# ...

# %%
# check the 'LanguageWorkedWith' column
df['HaveWorkedLanguage'].head()
# Out:
# 0                            Swift
# 1    JavaScript; Python; Ruby; SQL
# 2                Java; PHP; Python
# 3           Matlab; Python; R; SQL
# 4                              NaN
# Name: HaveWorkedLanguage, dtype: object

# %%
# Split the languages and create a list of all languages mentioned

language = df.HaveWorkedLanguage.str.split(';', expand=True).stack()

# Count the occurrences of each language

language_counts = languages.value_counts()
print(language_counts)
# Out:
#  SQL              18466
#  JavaScript       17159
#  Python           10719
#  PHP               9765
#  Java              8622
#                   ...
# F#                   24
# Hack                 22
# TypeScript            9
# Visual Basic 6        8
# Rust                  4
# Name: count, Length: 69, dtype: int64

# %%
# Show the most popular languages 
most_popular_languages=language_counts.head(10)
print(most_popular_laguages)
# Out:
#  SQL           18466
#  JavaScript    17159
#  Python        10719
#  PHP            9765
#  Java           8622
# C#              8596
# Java            5902
# JavaScript      5716
# C               5563
#  C++            4628
# Name: count, dtype: int64

# %%
# Visualize the most popular languages
import matplotlib.pyplot as plt

most_popular_languages.plot(kind='barh', color='darkblue')
plt.title('Most Popular Programming Languages')
plt.xlabel('Number of Developers')
plt.show()
